# %% [markdown]
# # Data cleaning Project 2

# %% [markdown]
# Prepared by:
#
# Name: Mohamed Elyass Mohamed Ahmed
#
# Passport: P06382503

# %% [markdown]
# ## Will do:

# %% [markdown]
# 1- Full data cleaning.

# %% [markdown]
# Deleting redundant columns.
#
# Renaming the columns.
#
# Dropping duplicates.
#
# Cleaning individual columns.
#
# Remove the NaN values from the dataset
#
# Check for some more Transformations

# %%
import numpy as np
import pandas as pd  
import matplotlib.pyplot as plt   
import seaborn as sns

# %%
df0 = pd.read_csv(r'C:\Users\HP\Downloads\archive (4).zip')

# %%
df0.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df0.shape
# Out:
# (1470, 35)

# %%
df0.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ## Remove the NaN values from the dataset

# %%
df0.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ## Deleting redundant columns.

# %%
df0.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
columns_to_keep = ['Age', 'Attrition', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField','Gender',  
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',  
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 
       'YearsWithCurrManager']
columns_to_drop = ['NumCompaniesWorked','EnvironmentSatisfaction', 'YearsInCurrentRole','EmployeeCount', 'EmployeeNumber','BusinessTravel','HourlyRate', 'YearsSinceLastPromotion']

# %%
df0[columns_to_keep]
df = df0[columns_to_keep]

# %%
df.head(5)
# Out:
#    Age Attrition  DailyRate              Department  DistanceFromHome  \
# 0   41       Yes       1102                   Sales                 1
# 1   49        No        279  Research & Development                 8
# 2   37       Yes       1373  Research & Development                 2
# 3   33        No       1392  Research & Development                 3
# 4   27        No        591  Research & Development                 2
#
#    Education EducationField  Gender  JobInvolvement  JobLevel  ...  \
# 0          2  Life Sciences  Female               3         2  ...
# 1          1  Life Sciences    Male               2         2  ...
# 2          2          Other    Male               2         1  ...
# 3          4  Life Sciences  Female               3         1  ...
# 4          1        Medical    Male               3         1  ...
#
#   PercentSalaryHike  PerformanceRating RelationshipSatisfaction  \
# 0                11                  3                        1
# ...

# %% [markdown]
# ## Renaming the columns.

# %%
df.rename(columns = {'EducationField':'Education Field', 'RelationshipSatisfaction' : 'Relationship Satisfaction'}, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3196\2492817402.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'EducationField':'Education Field', 'RelationshipSatisfaction' : 'Relationship Satisfaction'}, inplace=True)

# %%
df.head()
# Out:
#    Age Attrition  DailyRate              Department  DistanceFromHome  \
# 0   41       Yes       1102                   Sales                 1
# 1   49        No        279  Research & Development                 8
# 2   37       Yes       1373  Research & Development                 2
# 3   33        No       1392  Research & Development                 3
# 4   27        No        591  Research & Development                 2
#
#    Education Education Field  Gender  JobInvolvement  JobLevel  ...  \
# 0          2   Life Sciences  Female               3         2  ...
# 1          1   Life Sciences    Male               2         2  ...
# 2          2           Other    Male               2         1  ...
# 3          4   Life Sciences  Female               3         1  ...
# 4          1         Medical    Male               3         1  ...
#
#   PercentSalaryHike  PerformanceRating Relationship Satisfaction  \
# 0                11                  3                         1
# ...

# %% [markdown]
# ## Looks bad, lets make it as previous..

# %%
df.rename(columns = {'Education Field':'EducationField', 'Relationship Satisfaction': 'RelationshipSatisfaction'}, inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3196\760408401.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {'Education Field':'EducationField', 'Relationship Satisfaction': 'RelationshipSatisfaction'}, inplace=True)

# %%
df.head()
# Out:
#    Age Attrition  DailyRate              Department  DistanceFromHome  \
# 0   41       Yes       1102                   Sales                 1
# 1   49        No        279  Research & Development                 8
# 2   37       Yes       1373  Research & Development                 2
# 3   33        No       1392  Research & Development                 3
# 4   27        No        591  Research & Development                 2
#
#    Education EducationField  Gender  JobInvolvement  JobLevel  ...  \
# 0          2  Life Sciences  Female               3         2  ...
# 1          1  Life Sciences    Male               2         2  ...
# 2          2          Other    Male               2         1  ...
# 3          4  Life Sciences  Female               3         1  ...
# 4          1        Medical    Male               3         1  ...
#
#   PercentSalaryHike  PerformanceRating RelationshipSatisfaction  \
# 0                11                  3                        1
# ...

# %% [markdown]
# ## Dropping duplicates.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3196\3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.dropna(inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3196\1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  Age Attrition  DailyRate              Department  \
# 0         0   41       Yes       1102                   Sales
# 1         1   49        No        279  Research & Development
# 2         2   37       Yes       1373  Research & Development
# 3         3   33        No       1392  Research & Development
# 4         4   27        No        591  Research & Development
# ...     ...  ...       ...        ...                     ...
# 1465   1465   36        No        884  Research & Development
# 1466   1466   39        No        613  Research & Development
# 1467   1467   27        No        155  Research & Development
# 1468   1468   49        No       1023                   Sales
# 1469   1469   34        No        628  Research & Development
#
#       DistanceFromHome  Education EducationField  Gender  JobInvolvement  ...  \
# 0                    1          2  Life Sciences  Female               3  ...
# ...

# %% [markdown]
# ## Cleaning individual columns.

# %%
df['Department'] = df['Department'].str.replace('Research & Development', 'Research and Development')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3196\1488886500.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Department'] = df['Department'].str.replace('Research & Development', 'Research and Development')

# %%
df.head()
# Out:
#    index  Age Attrition  DailyRate                Department  \
# 0      0   41       Yes       1102                     Sales
# 1      1   49        No        279  Research and Development
# 2      2   37       Yes       1373  Research and Development
# 3      3   33        No       1392  Research and Development
# 4      4   27        No        591  Research and Development
#
#    DistanceFromHome  Education EducationField  Gender  JobInvolvement  ...  \
# 0                 1          2  Life Sciences  Female               3  ...
# 1                 8          1  Life Sciences    Male               2  ...
# 2                 2          2          Other    Male               2  ...
# 3                 3          4  Life Sciences  Female               3  ...
# 4                 2          1        Medical    Male               3  ...
#
#    PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 0                 11                 3                         1
# ...

# %%
df['Gender']= df['Gender'].str.upper()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3196\1879628960.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender']= df['Gender'].str.upper()

# %%
df.head()
# Out:
#    index  Age Attrition  DailyRate                Department  \
# 0      0   41       Yes       1102                     Sales
# 1      1   49        No        279  Research and Development
# 2      2   37       Yes       1373  Research and Development
# 3      3   33        No       1392  Research and Development
# 4      4   27        No        591  Research and Development
#
#    DistanceFromHome  Education EducationField  Gender  JobInvolvement  ...  \
# 0                 1          2  Life Sciences  FEMALE               3  ...
# 1                 8          1  Life Sciences    MALE               2  ...
# 2                 2          2          Other    MALE               2  ...
# 3                 3          4  Life Sciences  FEMALE               3  ...
# 4                 2          1        Medical    MALE               3  ...
#
#    PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 0                 11                 3                         1
# ...

# %% [markdown]
# ## Check for some more Transformations

# %%
df['Attrition'] = df['Attrition'].apply(lambda x : 1 if x == 'Yes' else 0)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3196\2801636249.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Attrition'] = df['Attrition'].apply(lambda x : 1 if x == 'Yes' else 0)

# %%
df.head()
# Out:
#    index  Age  Attrition  DailyRate                Department  \
# 0      0   41          1       1102                     Sales
# 1      1   49          0        279  Research and Development
# 2      2   37          1       1373  Research and Development
# 3      3   33          0       1392  Research and Development
# 4      4   27          0        591  Research and Development
#
#    DistanceFromHome  Education EducationField  Gender  JobInvolvement  ...  \
# 0                 1          2  Life Sciences  FEMALE               3  ...
# 1                 8          1  Life Sciences    MALE               2  ...
# 2                 2          2          Other    MALE               2  ...
# 3                 3          4  Life Sciences  FEMALE               3  ...
# 4                 2          1        Medical    MALE               3  ...
#
#    PercentSalaryHike PerformanceRating  RelationshipSatisfaction  \
# 0                 11                 3                         1
# ...

# %% [markdown]
# ## Above step is very useful for ML model training, it was just a smaple
